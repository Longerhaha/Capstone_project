# %% [markdown]
# ### 用来测试图片的排列序数

# %%
root_src = 'D:\Dogs vs. Cats'
import os
import shutil
import time
os.chdir(root_src)

# %%
train_filenames = os.listdir('train')
for i in range(10):
    print(train_filenames[i])
print('the number of train picture file is %d'%len(train_filenames))
# Out:
# cat.0.jpg
# cat.1.jpg
# cat.10.jpg
# cat.100.jpg
# cat.1000.jpg
# cat.10000.jpg
# cat.10001.jpg
# cat.10002.jpg
# cat.10003.jpg
# cat.10004.jpg
# the number of train picture file is 25000

# %%
test_filenames = os.listdir('test./test2')
for i in range(10):
    print(test_filenames[i])
print('the number of testpicture file is %d'%len(test_filenames))
# Out:
# 1.jpg
# 10.jpg
# 100.jpg
# 1000.jpg
# 10000.jpg
# 10001.jpg
# 10002.jpg
# 10003.jpg
# 10004.jpg
# 10005.jpg
# the number of testpicture file is 12500

# %% [markdown]
# ### 可视化一些训练集图片，从中可以看出来图片大小是不一样的，但是我们可以使用keras中的[图片生成器](https://keras.io/preprocessing/image/),其能够将猫狗图片reshape成一样大小的图片。

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

train_pic_num = len(train_filenames)
for i in range(15):
    plt.subplot(3, 5, i+1)
    index = random.randint(0, train_pic_num-1)
    name = train_filenames[index].split('.')[0]
    img = plt.imread('./train/'+train_filenames[index])
    plt.title(name)
    plt.imshow(img)
    plt.axis('off')
